# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
wholesale_customers = fetch_ucirepo(id=292)

# data (as pandas dataframes)
X = wholesale_customers.data.features
y = wholesale_customers.data.targets

# metadata
print(wholesale_customers.metadata)

# variable information
print(wholesale_customers.variables)
# Out:
# {'uci_id': 292, 'name': 'Wholesale customers', 'repository_url': 'https://archive.ics.uci.edu/dataset/292/wholesale+customers', 'data_url': 'https://archive.ics.uci.edu/static/public/292/data.csv', 'abstract': 'The data set refers to clients of a wholesale distributor. It includes the annual spending in monetary units (m.u.) on diverse product categories', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate'], 'num_instances': 440, 'num_features': 7, 'feature_types': ['Integer'], 'demographics': [], 'target_col': ['Region'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2013, 'last_updated': 'Mon Feb 05 2024', 'dataset_doi': '10.24432/C5030X', 'creators': ['Margarida Cardoso'], 'intro_paper': None, 'additional_info': {'summary': None, 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description
# ...

# %%
data=wholesale_customers.data.original

# %%
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
import pandas as pd

# %%
multi_index = pd.MultiIndex.from_product([['No Data Pre Processing','Normalized-zscore','Normalized-minmax','Normalized-maxabs','PCA-linear','PCA-incremental','tranformation-yeo','transformation-quantile','Normalized-zscore + tranformation-yeo',
    'Normalized-zscore + PCA-linear','Normalized-zscore + tranformation-yeo + PCA-linear'], ['c=3', 'c=4', 'c=5', 'c=6']])

df = pd.DataFrame(index=['Silhouette', 'Calinski-Harabasz', 'Davies-Bouldin'], columns=multi_index)
df.index_name='Paramters'

# %%
df
# Out:
#                   No Data Pre Processing                Normalized-zscore  \
#                                      c=3  c=4  c=5  c=6               c=3
# Silhouette                           NaN  NaN  NaN  NaN               NaN
# Calinski-Harabasz                    NaN  NaN  NaN  NaN               NaN
# Davies-Bouldin                       NaN  NaN  NaN  NaN               NaN
#
#                                  Normalized-minmax       ...  \
#                    c=4  c=5  c=6               c=3  c=4  ...
# Silhouette         NaN  NaN  NaN               NaN  NaN  ...
# Calinski-Harabasz  NaN  NaN  NaN               NaN  NaN  ...
# Davies-Bouldin     NaN  NaN  NaN               NaN  NaN  ...
#
#                   Normalized-zscore + tranformation-yeo       \
#                                                     c=5  c=6
# Silhouette                                          NaN  NaN
# Calinski-Harabasz                                   NaN  NaN
# ...

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
from pycaret.clustering import *
AffinityPropagationParameters = setup(data)
# Out:
# <style type="text/css">
# #T_33bd1_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_33bd1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33bd1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_33bd1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33bd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33bd1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_33bd1_row0_col1" class="data row0 col1" >919</td>
#     </tr>
#     <tr>
#       <th id="T_33bd1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33bd1_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_33bd1_row1_col1" class="data row1 col1" >(440, 8)</td>
#     </tr>
#     <tr>
# ...

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5385" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5385_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5385_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5385_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5385_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5385_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5385_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5385_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5385_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_a5385_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=3')] = 0.2340
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=3')] = 196.8248
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=3')] = 0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_3dedf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dedf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3dedf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3dedf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3dedf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3dedf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3dedf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dedf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dedf_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_3dedf_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=4')] = 0.2340
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=4')] = 196.8248
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=4')] = 0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1737" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1737_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a1737_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a1737_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a1737_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a1737_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a1737_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1737_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1737_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_a1737_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=5')] = 0.2340
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=5')] = 196.8248
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=5')] =0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_3f365" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f365_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3f365_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3f365_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3f365_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3f365_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3f365_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f365_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f365_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_3f365_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=6')] = 0.2340
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=6')] = 196.8248
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=6')] = 0.7978

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(AffinityPropagationModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(AffinityPropagationModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
AffinityPropagationParameters=setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3634" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3634_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d3634_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d3634_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d3634_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d3634_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d3634_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3634_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3634_row0_col0" class="data row0 col0" >0.2627</td>
#       <td id="T_d3634_row0_col1" class="data row0 col1" >114.3427</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=3')] = 0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=3')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=3')] = 0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d45a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d45a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6d45a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6d45a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6d45a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6d45a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6d45a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d45a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d45a_row0_col0" class="data row0 col0" >0.2627</td>
#       <td id="T_6d45a_row0_col1" class="data row0 col1" >114.3427</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=4')] = 0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=4')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=4')] = 0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee072" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee072_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ee072_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ee072_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ee072_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ee072_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ee072_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee072_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee072_row0_col0" class="data row0 col0" >0.2627</td>
#       <td id="T_ee072_row0_col1" class="data row0 col1" >114.3427</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=5')] = 0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=5')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=5')] = 0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a81d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a81d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9a81d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9a81d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9a81d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9a81d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9a81d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a81d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a81d_row0_col0" class="data row0 col0" >0.2627</td>
#       <td id="T_9a81d_row0_col1" class="data row0 col1" >114.3427</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=6')] = 0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=6')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=6')] = 0.8759

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, normalize = True, normalize_method = 'minmax', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f8e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f8e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7f8e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7f8e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7f8e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7f8e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7f8e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f8e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f8e3_row0_col0" class="data row0 col0" >0.4610</td>
#       <td id="T_7f8e3_row0_col1" class="data row0 col1" >785.3246</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=3')] = 0.4610
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=3')] = 785.3246
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=3')] =0.7936

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_cbd6e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbd6e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cbd6e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cbd6e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cbd6e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cbd6e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cbd6e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbd6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbd6e_row0_col0" class="data row0 col0" >0.4610</td>
#       <td id="T_cbd6e_row0_col1" class="data row0 col1" >785.3246</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=4')] = 0.4610
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=4')] = 785.3246
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=4')] = 0.7936

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e238" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e238_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5e238_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5e238_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5e238_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5e238_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5e238_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e238_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e238_row0_col0" class="data row0 col0" >0.4610</td>
#       <td id="T_5e238_row0_col1" class="data row0 col1" >785.3246</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=5')] =0.4610
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=5')] = 785.3246
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=5')] = 0.7936

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_69a8b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69a8b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_69a8b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_69a8b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_69a8b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_69a8b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_69a8b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69a8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69a8b_row0_col0" class="data row0 col0" >0.4610</td>
#       <td id="T_69a8b_row0_col1" class="data row0 col1" >785.3246</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=6')] =0.4610
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=6')] =785.3246
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=6')] =0.7936

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, normalize = True, normalize_method = 'maxabs', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_f433a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f433a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f433a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f433a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f433a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f433a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f433a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f433a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f433a_row0_col0" class="data row0 col0" >0.2950</td>
#       <td id="T_f433a_row0_col1" class="data row0 col1" >291.7248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=3')] = 0.2950
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=3')] = 291.7248
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=3')] = 0.8630

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_1424a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1424a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1424a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1424a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1424a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1424a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1424a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1424a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1424a_row0_col0" class="data row0 col0" >0.2950</td>
#       <td id="T_1424a_row0_col1" class="data row0 col1" >291.7248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=4')] =0.2950
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=4')] = 291.7248
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=4')] = 0.8630

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffe7a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffe7a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ffe7a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ffe7a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ffe7a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ffe7a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ffe7a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffe7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffe7a_row0_col0" class="data row0 col0" >0.2950</td>
#       <td id="T_ffe7a_row0_col1" class="data row0 col1" >291.7248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=5')] =0.2950
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=5')] =291.7248
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=5')] =0.8630

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b663e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b663e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b663e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b663e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b663e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b663e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b663e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b663e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b663e_row0_col0" class="data row0 col0" >0.2950</td>
#       <td id="T_b663e_row0_col1" class="data row0 col1" >291.7248</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=6')] =0.2950
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=6')] =291.7248
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=6')] = 0.8630

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, pca = True, pca_method = 'linear', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_87f60" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87f60_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_87f60_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_87f60_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_87f60_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_87f60_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_87f60_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87f60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87f60_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_87f60_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=3')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=3')] =196.8248
df.loc['Davies-Bouldin', ('PCA-linear', 'c=3')] =0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_f646c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f646c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f646c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f646c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f646c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f646c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f646c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f646c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f646c_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_f646c_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=4')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=4')] =196.8248
df.loc['Davies-Bouldin', ('PCA-linear', 'c=4')] =0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_49685" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49685_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_49685_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_49685_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_49685_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_49685_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_49685_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49685_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49685_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_49685_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=5')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=5')] = 196.8248
df.loc['Davies-Bouldin', ('PCA-linear', 'c=5')] = 0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3073" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3073_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f3073_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f3073_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f3073_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f3073_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f3073_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3073_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3073_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_f3073_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
df.loc['Silhouette', ('PCA-linear', 'c=6')] =0.2340
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=6')] =196.8248
df.loc['Davies-Bouldin', ('PCA-linear', 'c=6')] =0.7978

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, pca = True, pca_method = 'incremental', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_609c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_609c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_609c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_609c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_609c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_609c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_609c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_609c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_609c0_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_609c0_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=3')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=3')] = 196.8248
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=3')] = 0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_94643" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94643_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_94643_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_94643_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_94643_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_94643_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_94643_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94643_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94643_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_94643_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=4')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=4')] = 196.8248
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=4')] =0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_7641f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7641f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7641f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7641f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7641f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7641f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7641f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7641f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7641f_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_7641f_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=5')] = 0.2340
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=5')] = 196.8248
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=5')] = 0.7978

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_561a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_561a3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_561a3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_561a3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_561a3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_561a3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_561a3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_561a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_561a3_row0_col0" class="data row0 col0" >0.2340</td>
#       <td id="T_561a3_row0_col1" class="data row0 col1" >196.8248</td>
# ...

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=6')] =0.2340
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=6')] =196.8248
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=6')] =0.7978

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, transformation= True, transformation_method = 'yeo-johnson', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_9365e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9365e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9365e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9365e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9365e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9365e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9365e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9365e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9365e_row0_col0" class="data row0 col0" >0.2777</td>
#       <td id="T_9365e_row0_col1" class="data row0 col1" >11338.0910</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=3')] =0.2777
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=3')] = 11338.0910
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=3')] = 1.0484

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_4529e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4529e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4529e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4529e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4529e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4529e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4529e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4529e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4529e_row0_col0" class="data row0 col0" >0.2777</td>
#       <td id="T_4529e_row0_col1" class="data row0 col1" >11338.0910</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=4')] =0.2777
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=4')] = 11338.0910
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=4')] = 1.0484

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c959" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c959_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7c959_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7c959_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7c959_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7c959_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7c959_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c959_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c959_row0_col0" class="data row0 col0" >0.2777</td>
#       <td id="T_7c959_row0_col1" class="data row0 col1" >11338.0910</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=5')] =0.2777
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=5')] = 11338.0910
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=5')] = 1.0484

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_98d65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98d65_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_98d65_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_98d65_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_98d65_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_98d65_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_98d65_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98d65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98d65_row0_col0" class="data row0 col0" >0.2777</td>
#       <td id="T_98d65_row0_col1" class="data row0 col1" >11338.0910</td>
# ...

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=6')] =0.2777
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=6')] = 11338.0910
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=6')] = 1.0484

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data, transformation= True, transformation_method = 'quantile', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_48daa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48daa_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48daa_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48daa_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48daa_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48daa_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48daa_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48daa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48daa_row0_col0" class="data row0 col0" >0.3620</td>
#       <td id="T_48daa_row0_col1" class="data row0 col1" >605.0139</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('transformation-quantile', 'c=3')] =0.3620
df.loc['Calinski-Harabasz', ('transformation-quantile', 'c=3')] = 605.0139
df.loc['Davies-Bouldin', ('transformation-quantile', 'c=3')] =1.0750

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_ccd3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccd3e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ccd3e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ccd3e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ccd3e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ccd3e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ccd3e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccd3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccd3e_row0_col0" class="data row0 col0" >0.3620</td>
#       <td id="T_ccd3e_row0_col1" class="data row0 col1" >605.0139</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('transformation-quantile', 'c=4')] =0.3620
df.loc['Calinski-Harabasz', ('transformation-quantile', 'c=4')] = 605.0139
df.loc['Davies-Bouldin', ('transformation-quantile', 'c=4')] =1.0750

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_2bdb2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bdb2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2bdb2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2bdb2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2bdb2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2bdb2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2bdb2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bdb2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bdb2_row0_col0" class="data row0 col0" >0.3620</td>
#       <td id="T_2bdb2_row0_col1" class="data row0 col1" >605.0139</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('transformation-quantile', 'c=5')] =0.3620
df.loc['Calinski-Harabasz', ('transformation-quantile', 'c=5')] = 605.0139
df.loc['Davies-Bouldin', ('transformation-quantile', 'c=5')] =1.0750

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_544e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_544e8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_544e8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_544e8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_544e8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_544e8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_544e8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_544e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_544e8_row0_col0" class="data row0 col0" >0.3620</td>
#       <td id="T_544e8_row0_col1" class="data row0 col1" >605.0139</td>
# ...

# %%
df.loc['Silhouette', ('transformation-quantile', 'c=6')] =0.3620
df.loc['Calinski-Harabasz', ('transformation-quantile', 'c=6')] = 605.0139
df.loc['Davies-Bouldin', ('transformation-quantile', 'c=6')] =1.0750

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data,normalize=True,normalize_method='zscore', transformation= True, transformation_method = 'yeo-johnson', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fac4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fac4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5fac4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5fac4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5fac4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5fac4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5fac4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fac4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fac4_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_5fac4_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=3')] = 0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=3')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=3')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d69c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d69c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3d69c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3d69c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3d69c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3d69c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3d69c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d69c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d69c_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_3d69c_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=4')] = 0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=4')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=4')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b0f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b0f7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9b0f7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9b0f7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9b0f7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9b0f7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9b0f7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b0f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b0f7_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_9b0f7_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=5')] = 0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=5')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=5')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5732e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5732e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5732e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5732e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5732e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5732e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5732e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5732e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5732e_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_5732e_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=6')] = 0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=6')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=6')] =1.3876

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data,normalize=True,normalize_method='zscore', pca= True, pca_method = 'linear', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7543" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7543_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a7543_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a7543_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a7543_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a7543_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a7543_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7543_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7543_row0_col0" class="data row0 col0" >0.2535</td>
#       <td id="T_a7543_row0_col1" class="data row0 col1" >105.7938</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=3')] =0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=3')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=3')] =0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5536" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5536_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b5536_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b5536_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b5536_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b5536_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b5536_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5536_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5536_row0_col0" class="data row0 col0" >0.2535</td>
#       <td id="T_b5536_row0_col1" class="data row0 col1" >105.7938</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=4')] =0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=4')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=4')] =0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f5d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f5d2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1f5d2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1f5d2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1f5d2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1f5d2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1f5d2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f5d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f5d2_row0_col0" class="data row0 col0" >0.2535</td>
#       <td id="T_1f5d2_row0_col1" class="data row0 col1" >105.7938</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=5')] =0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=5')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=5')] =0.8759

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7fd9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7fd9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b7fd9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b7fd9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b7fd9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b7fd9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b7fd9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7fd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7fd9_row0_col0" class="data row0 col0" >0.2535</td>
#       <td id="T_b7fd9_row0_col1" class="data row0 col1" >105.7938</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=6')] =0.2627
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=6')] = 114.3427
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=6')] =0.8759

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
AffinityPropagationParameters=setup(data = data,normalize=True,normalize_method='zscore', pca= True, pca_method = 'linear',transformation=True,transformation_method='yeo-johnson', verbose=False)

# %%
AffinityPropagationModel = create_model('ap', num_clusters=3)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b624" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b624_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5b624_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5b624_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5b624_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5b624_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5b624_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b624_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b624_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_5b624_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] =0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=4)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b067a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b067a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b067a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b067a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b067a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b067a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b067a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b067a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b067a_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_b067a_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=5)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bfe8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bfe8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6bfe8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6bfe8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6bfe8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6bfe8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6bfe8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bfe8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bfe8_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_6bfe8_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] =0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] =1.3876

# %%
AffinityPropagationModel = create_model('ap', num_clusters=6)
apPrediction = assign_model(AffinityPropagationModel)
apPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_7be4f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7be4f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7be4f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7be4f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7be4f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7be4f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7be4f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7be4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7be4f_row0_col0" class="data row0 col0" >0.1568</td>
#       <td id="T_7be4f_row0_col1" class="data row0 col1" >49.3278</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =0.1568
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =49.3278
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =1.3876

# %%
evaluate_model(AffinityPropagationModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df
# Out:
#                   No Data Pre Processing                                \
#                                      c=3       c=4       c=5       c=6
# Silhouette                         0.234     0.234     0.234     0.234
# Calinski-Harabasz               196.8248  196.8248  196.8248  196.8248
# Davies-Bouldin                    0.7978    0.7978    0.7978    0.7978
#
#                   Normalized-zscore                                \
#                                 c=3       c=4       c=5       c=6
# Silhouette                   0.2627    0.2627    0.2627    0.2627
# Calinski-Harabasz          114.3427  114.3427  114.3427  114.3427
# Davies-Bouldin               0.8759    0.8759    0.8759    0.8759
#
#                   Normalized-minmax            ...  \
#                                 c=3       c=4  ...
# Silhouette                    0.461     0.461  ...
# Calinski-Harabasz          785.3246  785.3246  ...
# Davies-Bouldin               0.7936    0.7936  ...
#
# ...

# %%
df.to_csv('apresult.csv')

# %%
df
# Out:
#                   No Data Pre Processing                                \
#                                      c=3       c=4       c=5       c=6
# Silhouette                         0.234     0.234     0.234     0.234
# Calinski-Harabasz               196.8248  196.8248  196.8248  196.8248
# Davies-Bouldin                    0.7978    0.7978    0.7978    0.7978
#
#                   Normalized-zscore                                \
#                                 c=3       c=4       c=5       c=6
# Silhouette                   0.2627    0.2627    0.2627    0.2627
# Calinski-Harabasz          114.3427  114.3427  114.3427  114.3427
# Davies-Bouldin               0.8759    0.8759    0.8759    0.8759
#
#                   Normalized-minmax            ...  \
#                                 c=3       c=4  ...
# Silhouette                    0.461     0.461  ...
# Calinski-Harabasz          785.3246  785.3246  ...
# Davies-Bouldin               0.7936    0.7936  ...
#
# ...
