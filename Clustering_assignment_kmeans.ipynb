# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
wholesale_customers = fetch_ucirepo(id=292)

# data (as pandas dataframes)
X = wholesale_customers.data.features
y = wholesale_customers.data.targets

# metadata
print(wholesale_customers.metadata)

# variable information
print(wholesale_customers.variables)
# Out:
# {'uci_id': 292, 'name': 'Wholesale customers', 'repository_url': 'https://archive.ics.uci.edu/dataset/292/wholesale+customers', 'data_url': 'https://archive.ics.uci.edu/static/public/292/data.csv', 'abstract': 'The data set refers to clients of a wholesale distributor. It includes the annual spending in monetary units (m.u.) on diverse product categories', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate'], 'num_instances': 440, 'num_features': 7, 'feature_types': ['Integer'], 'demographics': [], 'target_col': ['Region'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2013, 'last_updated': 'Mon Feb 05 2024', 'dataset_doi': '10.24432/C5030X', 'creators': ['Margarida Cardoso'], 'intro_paper': None, 'additional_info': {'summary': None, 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description
# ...

# %%
data=wholesale_customers.data.original

# %%
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
import pandas as pd

# %%
multi_index = pd.MultiIndex.from_product([['No Data Pre Processing','Normalized-zscore','Normalized-minmax','Normalized-maxabs','PCA-linear','PCA-incremental','tranformation-yeo','tranformation-quantile','Normalized-zscore + tranformation-yeo',
    'Normalized-zscore + PCA-linear','Normalized-zscore + tranformation-yeo + PCA-linear'], ['c=3', 'c=4', 'c=5', 'c=6']])

df = pd.DataFrame(index=['Silhouette', 'Calinski-Harabasz', 'Davies-Bouldin'], columns=multi_index)
df.index_name='Paramters'

# %%
df
# Out:
#                   No Data Pre Processing                Normalized-zscore  \
#                                      c=3  c=4  c=5  c=6               c=3
# Silhouette                           NaN  NaN  NaN  NaN               NaN
# Calinski-Harabasz                    NaN  NaN  NaN  NaN               NaN
# Davies-Bouldin                       NaN  NaN  NaN  NaN               NaN
#
#                                  Normalized-minmax       ...  \
#                    c=4  c=5  c=6               c=3  c=4  ...
# Silhouette         NaN  NaN  NaN               NaN  NaN  ...
# Calinski-Harabasz  NaN  NaN  NaN               NaN  NaN  ...
# Davies-Bouldin     NaN  NaN  NaN               NaN  NaN  ...
#
#                   Normalized-zscore + tranformation-yeo       \
#                                                     c=5  c=6
# Silhouette                                          NaN  NaN
# Calinski-Harabasz                                   NaN  NaN
# ...

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(data)
# Out:
# <style type="text/css">
# #T_ae24d_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ae24d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae24d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ae24d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae24d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae24d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ae24d_row0_col1" class="data row0 col1" >7237</td>
#     </tr>
#     <tr>
#       <th id="T_ae24d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae24d_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_ae24d_row1_col1" class="data row1 col1" >(440, 8)</td>
#     </tr>
#     <tr>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd897" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd897_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fd897_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fd897_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fd897_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fd897_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fd897_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd897_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd897_row0_col0" class="data row0 col0" >0.4784</td>
#       <td id="T_fd897_row0_col1" class="data row0 col1" >210.1526</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=3')] = 0.4784
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=3')] = 210.1526
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=3')] = 0.8895

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5c61" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5c61_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f5c61_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f5c61_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f5c61_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f5c61_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f5c61_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5c61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5c61_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_f5c61_row0_col1" class="data row0 col1" >207.8197</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=4')] = 0.3866
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=4')] = 207.8197
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=4')] = 0.9543

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6262" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6262_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a6262_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a6262_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a6262_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a6262_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a6262_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6262_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6262_row0_col0" class="data row0 col0" >0.3878</td>
#       <td id="T_a6262_row0_col1" class="data row0 col1" >214.2765</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=5')] = 0.3833
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=5')] = 215.0578
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=5')] = 0.9020

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_becc5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_becc5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_becc5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_becc5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_becc5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_becc5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_becc5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_becc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_becc5_row0_col0" class="data row0 col0" >0.3830</td>
#       <td id="T_becc5_row0_col1" class="data row0 col1" >204.4015</td>
# ...

# %%
df.loc['Silhouette', ('No Data Pre Processing', 'c=6')] = 0.3866
df.loc['Calinski-Harabasz', ('No Data Pre Processing', 'c=6')] = 207.8197
df.loc['Davies-Bouldin', ('No Data Pre Processing', 'c=6')] = 0.9543

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
plot_model(KMeanClusteringModel, plot = 'silhouette')

# %%
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kMeanClusteringParameters=setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_87e21" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87e21_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_87e21_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_87e21_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_87e21_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_87e21_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_87e21_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87e21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87e21_row0_col0" class="data row0 col0" >0.3568</td>
#       <td id="T_87e21_row0_col1" class="data row0 col1" >139.3494</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=3')] = 0.3568
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=3')] = 139.3494
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=3')] = 1.1736

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ca88" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ca88_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8ca88_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8ca88_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8ca88_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8ca88_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8ca88_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ca88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ca88_row0_col0" class="data row0 col0" >0.3683</td>
#       <td id="T_8ca88_row0_col1" class="data row0 col1" >131.5821</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=4')] = 0.3683
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=4')] = 131.5821
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=4')] = 1.1454

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_99850" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99850_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_99850_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_99850_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_99850_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_99850_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_99850_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99850_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99850_row0_col0" class="data row0 col0" >0.3525</td>
#       <td id="T_99850_row0_col1" class="data row0 col1" >137.9514</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=5')] = 0.3529
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=5')] = 137.9523
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=5')] = 1.1481

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_80506" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80506_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_80506_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_80506_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_80506_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_80506_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_80506_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80506_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80506_row0_col0" class="data row0 col0" >0.3516</td>
#       <td id="T_80506_row0_col1" class="data row0 col1" >145.7303</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore', 'c=6')] = 0.3572
df.loc['Calinski-Harabasz', ('Normalized-zscore', 'c=6')] = 144.7005
df.loc['Davies-Bouldin', ('Normalized-zscore', 'c=6')] = 0.8788

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, normalize = True, normalize_method = 'minmax', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_75720" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75720_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_75720_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_75720_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_75720_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_75720_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_75720_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75720_row0_col0" class="data row0 col0" >0.6593</td>
#       <td id="T_75720_row0_col1" class="data row0 col1" >760.0331</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=3')] = 0.6593
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=3')] = 760.0331
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=3')] = 0.5097

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_20514" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20514_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_20514_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_20514_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_20514_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_20514_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_20514_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20514_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20514_row0_col0" class="data row0 col0" >0.6800</td>
#       <td id="T_20514_row0_col1" class="data row0 col1" >877.9768</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=4')] = 0.6800
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=4')] = 877.9768
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=4')] = 0.6110

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bb86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bb86_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6bb86_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6bb86_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6bb86_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6bb86_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6bb86_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bb86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bb86_row0_col0" class="data row0 col0" >0.6468</td>
#       <td id="T_6bb86_row0_col1" class="data row0 col1" >825.8484</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=5')] = 0.6468
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=5')] = 825.8484
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=5')] = 0.5923

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bc65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bc65_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8bc65_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8bc65_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8bc65_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8bc65_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8bc65_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bc65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bc65_row0_col0" class="data row0 col0" >0.6535</td>
#       <td id="T_8bc65_row0_col1" class="data row0 col1" >831.3299</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-minmax', 'c=6')] = 0.6535
df.loc['Calinski-Harabasz', ('Normalized-minmax', 'c=6')] =831.3299
df.loc['Davies-Bouldin', ('Normalized-minmax', 'c=6')] = 0.6337

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, normalize = True, normalize_method = 'maxabs', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_78c5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c5b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_78c5b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_78c5b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_78c5b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_78c5b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_78c5b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78c5b_row0_col0" class="data row0 col0" >0.5550</td>
#       <td id="T_78c5b_row0_col1" class="data row0 col1" >383.7182</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=3')] = 0.5545
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=3')] = 383.8222
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=3')] = 0.7116

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d0f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d0f6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3d0f6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3d0f6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3d0f6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3d0f6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3d0f6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d0f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d0f6_row0_col0" class="data row0 col0" >0.5799</td>
#       <td id="T_3d0f6_row0_col1" class="data row0 col1" >357.2453</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=4')] = 0.5799
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=4')] = 357.2453
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=4')] = 0.8165

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbe42" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbe42_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bbe42_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bbe42_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bbe42_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bbe42_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bbe42_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbe42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbe42_row0_col0" class="data row0 col0" >0.5885</td>
#       <td id="T_bbe42_row0_col1" class="data row0 col1" >352.1927</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=5')] = 0.5885
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=5')] = 352.1927
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=5')] = 0.7520

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a197" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a197_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8a197_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8a197_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8a197_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8a197_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8a197_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a197_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a197_row0_col0" class="data row0 col0" >0.5350</td>
#       <td id="T_8a197_row0_col1" class="data row0 col1" >344.6292</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-maxabs', 'c=6')] =0.5350
df.loc['Calinski-Harabasz', ('Normalized-maxabs', 'c=6')] =344.6292
df.loc['Davies-Bouldin', ('Normalized-maxabs', 'c=6')] = 0.8882

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, pca = True, pca_method = 'linear', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_13b85" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13b85_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_13b85_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_13b85_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_13b85_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_13b85_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_13b85_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13b85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13b85_row0_col0" class="data row0 col0" >0.4784</td>
#       <td id="T_13b85_row0_col1" class="data row0 col1" >210.1526</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=3')] = 0.4798
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=3')] = 210.1480
df.loc['Davies-Bouldin', ('PCA-linear', 'c=3')] = 0.8889

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_faccf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faccf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_faccf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_faccf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_faccf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_faccf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_faccf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faccf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faccf_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_faccf_row0_col1" class="data row0 col1" >207.8197</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=4')] = 0.3866
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=4')] = 207.8197
df.loc['Davies-Bouldin', ('PCA-linear', 'c=4')] =0.9543

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b170" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b170_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0b170_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0b170_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0b170_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0b170_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0b170_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b170_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b170_row0_col0" class="data row0 col0" >0.3635</td>
#       <td id="T_0b170_row0_col1" class="data row0 col1" >214.0612</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-linear', 'c=5')] = 0.3866
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=5')] = 214.1993
df.loc['Davies-Bouldin', ('PCA-linear', 'c=5')] = 0.8873

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c1fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c1fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8c1fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8c1fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8c1fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8c1fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8c1fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c1fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c1fe_row0_col0" class="data row0 col0" >0.3766</td>
#       <td id="T_8c1fe_row0_col1" class="data row0 col1" >205.6540</td>
# ...

# %%
df.loc['Silhouette', ('PCA-linear', 'c=6')] =0.3751
df.loc['Calinski-Harabasz', ('PCA-linear', 'c=6')] =205.7447
df.loc['Davies-Bouldin', ('PCA-linear', 'c=6')] =0.8519

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, pca = True, pca_method = 'incremental', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_95689" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95689_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95689_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95689_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95689_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95689_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95689_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95689_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95689_row0_col0" class="data row0 col0" >0.4784</td>
#       <td id="T_95689_row0_col1" class="data row0 col1" >210.1526</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=3')] = 0.4784
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=3')] = 210.1526
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=3')] = 0.8895

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ddc9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ddc9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ddc9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ddc9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ddc9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ddc9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ddc9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ddc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ddc9_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_5ddc9_row0_col1" class="data row0 col1" >207.8197</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=4')] =0.3866
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=4')] = 207.8197
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=4')] =0.9543

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e13f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e13f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4e13f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4e13f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4e13f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4e13f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4e13f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e13f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e13f_row0_col0" class="data row0 col0" >0.3690</td>
#       <td id="T_4e13f_row0_col1" class="data row0 col1" >213.9071</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=5')] = 0.3706
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=5')] = 214.5350
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=5')] = 0.9108

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_18849" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18849_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_18849_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_18849_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_18849_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_18849_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_18849_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18849_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18849_row0_col0" class="data row0 col0" >0.3344</td>
#       <td id="T_18849_row0_col1" class="data row0 col1" >201.6360</td>
# ...

# %%
df.loc['Silhouette', ('PCA-incremental', 'c=6')] =0.3853
df.loc['Calinski-Harabasz', ('PCA-incremental', 'c=6')] =203.1944
df.loc['Davies-Bouldin', ('PCA-incremental', 'c=6')] =0.8514

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, transformation= True, transformation_method = 'yeo-johnson', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_058ba" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_058ba_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_058ba_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_058ba_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_058ba_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_058ba_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_058ba_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_058ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_058ba_row0_col0" class="data row0 col0" >0.8554</td>
#       <td id="T_058ba_row0_col1" class="data row0 col1" >13039.7633</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=3')] = 0.8554
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=3')] = 13039.7633
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=3')] = 0.3389

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e22a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e22a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1e22a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1e22a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1e22a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1e22a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1e22a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e22a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e22a_row0_col0" class="data row0 col0" >0.5181</td>
#       <td id="T_1e22a_row0_col1" class="data row0 col1" >15162.6315</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=4')] =0.5181
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=4')] = 15162.6315
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=4')] =0.6203

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6527a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6527a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6527a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6527a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6527a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6527a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6527a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6527a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6527a_row0_col0" class="data row0 col0" >0.4620</td>
#       <td id="T_6527a_row0_col1" class="data row0 col1" >14221.6229</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=5')] = 0.4635
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=5')] = 14221.5560
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=5')] = 0.6936

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9cb2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9cb2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9cb2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9cb2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9cb2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9cb2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9cb2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9cb2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9cb2_row0_col0" class="data row0 col0" >0.4166</td>
#       <td id="T_b9cb2_row0_col1" class="data row0 col1" >13921.3952</td>
# ...

# %%
df.loc['Silhouette', ('tranformation-yeo', 'c=6')] =0.4158
df.loc['Calinski-Harabasz', ('tranformation-yeo', 'c=6')] =13907.8700
df.loc['Davies-Bouldin', ('tranformation-yeo', 'c=6')] =0.7501

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data, transformation= True, transformation_method = 'quantile', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_320de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_320de_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_320de_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_320de_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_320de_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_320de_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_320de_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_320de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_320de_row0_col0" class="data row0 col0" >0.6085</td>
#       <td id="T_320de_row0_col1" class="data row0 col1" >747.5305</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-quantile', 'c=3')] = 0.6085
df.loc['Calinski-Harabasz', ('tranformation-quantile', 'c=3')] = 747.5305
df.loc['Davies-Bouldin', ('tranformation-quantile', 'c=3')] =0.5590

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_81637" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81637_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_81637_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_81637_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_81637_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_81637_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_81637_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81637_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81637_row0_col0" class="data row0 col0" >0.6377</td>
#       <td id="T_81637_row0_col1" class="data row0 col1" >899.6002</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-quantile', 'c=4')] =0.6377
df.loc['Calinski-Harabasz', ('tranformation-quantile', 'c=4')] = 899.6002
df.loc['Davies-Bouldin', ('tranformation-quantile', 'c=4')] =0.5808

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4350" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4350_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e4350_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e4350_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e4350_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e4350_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e4350_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4350_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4350_row0_col0" class="data row0 col0" >0.5586</td>
#       <td id="T_e4350_row0_col1" class="data row0 col1" >792.4932</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('tranformation-quantile', 'c=5')] = 0.5586
df.loc['Calinski-Harabasz', ('tranformation-quantile', 'c=5')] = 792.4932
df.loc['Davies-Bouldin', ('tranformation-quantile', 'c=5')] = 0.7147

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe233" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe233_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fe233_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fe233_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fe233_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fe233_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fe233_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe233_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe233_row0_col0" class="data row0 col0" >0.4057</td>
#       <td id="T_fe233_row0_col1" class="data row0 col1" >724.1610</td>
# ...

# %%
df.loc['Silhouette', ('tranformation-quantile', 'c=6')] =0.4009
df.loc['Calinski-Harabasz', ('tranformation-quantile', 'c=6')] =724.2110
df.loc['Davies-Bouldin', ('tranformation-quantile', 'c=6')] =0.9993

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data,normalize=True,normalize_method='zscore', transformation= True, transformation_method = 'yeo-johnson', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e5fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e5fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4e5fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4e5fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4e5fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4e5fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4e5fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e5fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e5fe_row0_col0" class="data row0 col0" >0.2228</td>
#       <td id="T_4e5fe_row0_col1" class="data row0 col1" >153.5484</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=3')] = 0.2228
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=3')] = 153.5484
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=3')] =1.6406

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f8d8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f8d8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6f8d8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6f8d8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6f8d8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6f8d8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6f8d8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f8d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f8d8_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_6f8d8_row0_col1" class="data row0 col1" >136.3422</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=4')] =0.2472
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=4')] = 136.3349
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=4')] =1.4208

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_e09f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e09f6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e09f6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e09f6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e09f6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e09f6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e09f6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e09f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e09f6_row0_col0" class="data row0 col0" >0.2167</td>
#       <td id="T_e09f6_row0_col1" class="data row0 col1" >121.1244</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=5')] = 0.2184
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=5')] = 121.2396
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=5')] =1.5850

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6781" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6781_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b6781_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b6781_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b6781_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b6781_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b6781_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6781_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6781_row0_col0" class="data row0 col0" >0.2017</td>
#       <td id="T_b6781_row0_col1" class="data row0 col1" >111.0965</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo', 'c=6')] =0.2033
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo', 'c=6')] =111.1239
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo', 'c=6')] =1.5945

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data,normalize=True,normalize_method='zscore', pca= True, pca_method = 'linear', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9483" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9483_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d9483_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d9483_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d9483_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d9483_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d9483_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9483_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9483_row0_col0" class="data row0 col0" >0.3568</td>
#       <td id="T_d9483_row0_col1" class="data row0 col1" >139.3494</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=3')] =0.3568
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=3')] = 139.3494
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=3')] =1.1736

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9c56" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9c56_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9c56_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9c56_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9c56_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9c56_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9c56_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9c56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9c56_row0_col0" class="data row0 col0" >0.3478</td>
#       <td id="T_b9c56_row0_col1" class="data row0 col1" >130.9300</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=4')] =0.3482
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=4')] = 130.9179
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=4')] =1.2359

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf468" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf468_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bf468_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bf468_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bf468_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bf468_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bf468_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf468_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf468_row0_col0" class="data row0 col0" >0.3529</td>
#       <td id="T_bf468_row0_col1" class="data row0 col1" >137.9523</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=5')] = 0.3688
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=5')] =138.3391
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=5')] =1.0586

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_eedf8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eedf8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_eedf8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_eedf8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_eedf8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_eedf8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_eedf8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eedf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eedf8_row0_col0" class="data row0 col0" >0.3516</td>
#       <td id="T_eedf8_row0_col1" class="data row0 col1" >145.7303</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + PCA-linear', 'c=6')] =0.3537
df.loc['Calinski-Harabasz', ('Normalized-zscore + PCA-linear', 'c=6')] =145.6033
df.loc['Davies-Bouldin', ('Normalized-zscore + PCA-linear', 'c=6')] =0.9748

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
kMeanClusteringParameters=setup(data = data,normalize=True,normalize_method='zscore', pca= True, pca_method = 'linear',transformation=True,transformation_method='yeo-johnson', verbose=False)

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=3)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_9906e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9906e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9906e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9906e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9906e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9906e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9906e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9906e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9906e_row0_col0" class="data row0 col0" >0.2229</td>
#       <td id="T_9906e_row0_col1" class="data row0 col1" >153.5594</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] =0.2228
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] = 153.5484
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=3')] =1.6406

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_809c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_809c0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_809c0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_809c0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_809c0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_809c0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_809c0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_809c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_809c0_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_809c0_row0_col1" class="data row0 col1" >136.3422</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =0.2476
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =136.3494
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=4')] =1.4215

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=5)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f89b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f89b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2f89b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2f89b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2f89b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2f89b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2f89b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f89b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f89b_row0_col0" class="data row0 col0" >0.2187</td>
#       <td id="T_2f89b_row0_col1" class="data row0 col1" >121.1591</td>
# ...

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] = 0.2187
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] =121.1591
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=5')] =1.5847

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=6)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_ce8ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce8ef_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ce8ef_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ce8ef_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ce8ef_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ce8ef_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ce8ef_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce8ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce8ef_row0_col0" class="data row0 col0" >0.2026</td>
#       <td id="T_ce8ef_row0_col1" class="data row0 col1" >111.1279</td>
# ...

# %%
df.loc['Silhouette', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =0.2013
df.loc['Calinski-Harabasz', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =111.0880
df.loc['Davies-Bouldin', ('Normalized-zscore + tranformation-yeo + PCA-linear', 'c=6')] =1.6011

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
df
# Out:
#                   No Data Pre Processing                                \
#                                      c=3       c=4       c=5       c=6
# Silhouette                        0.4784    0.3866    0.3833    0.3866
# Calinski-Harabasz               210.1526  207.8197  215.0578  207.8197
# Davies-Bouldin                    0.8895    0.9543     0.902    0.9543
#
#                   Normalized-zscore                                \
#                                 c=3       c=4       c=5       c=6
# Silhouette                   0.3568    0.3683    0.3529    0.3572
# Calinski-Harabasz          139.3494  131.5821  137.9523  144.7005
# Davies-Bouldin               1.1736    1.1454    1.1481    0.8788
#
#                   Normalized-minmax            ...  \
#                                 c=3       c=4  ...
# Silhouette                   0.6593      0.68  ...
# Calinski-Harabasz          760.0331  877.9768  ...
# Davies-Bouldin               0.5097     0.611  ...
#
# ...

# %%
df.to_csv('kmeansresult.csv')
